# %% [markdown]
# <a href="https://colab.research.google.com/github/RitzyTr/Projeto_Saude_Mental/blob/main/Projeto_Saude_Mental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***PREPARAÇÃO*** ***DOS*** ***DADOS***

# %% [markdown]
# ##IMPORTAÇÃO E CRIAÇÃO DO DATAFRAME
#
# ---

# %%
import pandas as pd

codebook = pd.read_csv('Codebook Carrard et al. 2022 MedTeach.csv', sep=';', engine='python')

dados = pd.read_csv('Data Carrard et al. 2022 MedTeach.csv')
df = pd.DataFrame(dados)
df
# Out:
#        id  age  year  sex  glang  part  job  stud_h  health  psyt  jspe  \
# 0       2   18     1    1    120     1    0      56       3     0    88
# 1       4   26     4    1      1     1    0      20       4     0   109
# 2       9   21     3    2      1     0    0      36       3     0   106
# 3      10   21     2    2      1     0    1      51       5     0   101
# 4      13   21     3    1      1     1    0      22       4     0   102
# ..    ...  ...   ...  ...    ...   ...  ...     ...     ...   ...   ...
# 881  1781   21     2    1      1     1    0      45       3     0   106
# 882  1785   20     2    2      1     0    0      13       3     0   113
# 883  1787   19     1    1      1     0    0      50       5     0   100
# 884  1789   24     5    2      1     0    0      20       2     1   120
# 885  1790   22     3    1      1     0    1      20       5     0   102
#
#      qcae_cog  qcae_aff  amsp  erec_mean  cesd  stai_t  mbi_ex  mbi_cy  mbi_ea
# 0          62        27    17   0.738095    34      61      17      13      20
# 1          55        37    22   0.690476     7      33      14      11      26
# 2          64        39    17   0.690476    25      73      24       7      23
# 3          52        33    18   0.833333    17      48      16      10      21
# 4          58        28    21   0.690476    14      46      22      14      23
# ..        ...       ...   ...        ...   ...     ...     ...     ...     ...
# 881        63        39    28   0.619048    41      39      23       4      34
# 882        67        40    21   0.809524    26      41      17       5      24
# 883        50        31    24   0.547619    14      45      15       8      31
# 884        64        39    21   0.785714    33      58      22      15      19
# 885        54        26    25   0.571429     5      27      11       9      30
#
# [886 rows x 20 columns]

# %% [markdown]
# ##SUBSTITUIÇÃO DE VALORES USANDO O CODEBOOK COMO PARÂMETRO

# %% [markdown]
# Excluindo colunas nulls do codebook

# %%
del codebook['Unnamed: 3']
del codebook['Unnamed: 4']
del codebook['Unnamed: 5']

# %%
codebook
# Out:
#    Variable Name                                     Variable Label  \
# 0             id                             Participants ID number
# 1            age                         age at questionnaire 20-21
# 2           year  CURICULUM YEAR : In which curriculum year are ...
# 3            sex  GENDER : To which gender do you identify the m...
# 4          glang         MOTHER TONGUE: What is your mother tongue?
# 5           part        PARTNERSHIP STATUS : Do you have a partner?
# 6            job             HAVING A JOB : Do you have a paid job?
# 7         stud_h  HOURS OF STUDY PER WEEK : On average, how many...
# 8         health  SATISFACTION WITH HEALTH : How satisfied are y...
# 9           psyt  PSYCHOTHERAPY LAST YEAR : During the last 12 m...
# 10          jspe                           JSPE total empathy score
# 11      qcae_cog                       QCAE Cognitive empathy score
# 12      qcae_aff                       QCAE Affective empathy score
# 13          amsp                                   AMSP total score
# 14     erec_mean             GERT : mean value of correct responses
# 15          cesd                                  CES-D total score
# 16        stai_t                                         STAI score
# 17        mbi_ex                           MBI Emotional Exhaustion
# 18        mbi_cy                                      MBI Cynicism
# 19        mbi_ea                             MBI Academic Efficacy
#
#                                        Variable Scale
# 0                                              string
# 1                                             numeric
# 2   1=Bmed1; 2=Bmed2; 3=Bmed3; 4=Mmed1; 5=Mmed2; 6...
# 3                        1=Man; 2=Woman; 3=Non-binary
# 4   1=French; 15=German; 20=English; 37=Arab; 51=B...
# 5                                         0=No; 1=Yes
# 6                                         0=No; 1=Yes
# 7                                                 NaN
# 8   1=Verydissatisfied; 2=Dissatisfied; 3=Neithers...
# 9                                         0=No; 1=Yes
# 10                                            numeric
# 11                                            numeric
# 12                                            numeric
# 13                                            numeric
# 14                                            numeric
# 15                                            numeric
# 16                                            numeric
# 17                                            numeric
# 18                                            numeric
# 19                                            numeric

# %% [markdown]
# Criando mapeamento de valores para substitui-los no conjunto de dados principal

# %%
# Criar um dicionário de mapeamento
codebook['Variable Scale'] = codebook['Variable Scale'].fillna('')

mapeamento = {}

for _, row in codebook.iterrows():
  variable_name = row['Variable Name']
  variable_labels = row['Variable Scale']

  if '=' in variable_labels:
    mapeamento[variable_name] = {
        int(k.strip()): v.strip() for k, v in
        (item.split('=') for item in variable_labels.split(';'))
    }

print(mapeamento)
# Out:
# {'year': {1: 'Bmed1', 2: 'Bmed2', 3: 'Bmed3', 4: 'Mmed1', 5: 'Mmed2', 6: 'Mmed3'}, 'sex': {1: 'Man', 2: 'Woman', 3: 'Non-binary'}, 'glang': {1: 'French', 15: 'German', 20: 'English', 37: 'Arab', 51: 'Basque', 52: 'Bulgarian', 53: 'Catalan', 54: 'Chinese', 59: 'Korean', 60: 'Croatian', 62: 'Danish', 63: 'Spanish', 82: 'Estonian', 83: 'Finnish', 84: 'Galician', 85: 'Greek', 86: 'Hebrew', 87: 'Hindi', 88: 'Hungarian', 89: 'Indonesian', 90: 'Italian', 92: 'Japanese', 93: 'Kazakh', 94: 'Latvian', 95: 'Lithuanian', 96: 'Malay', 98: 'Dutch', 100: 'Norwegian', 101: 'Polish', 102: 'Portuguese', 104: 'Romanian', 106: 'Russian', 108: 'Serbian', 112: 'Slovak', 113: 'Slovenian', 114: 'Swedish', 116: 'Czech', 117: 'Thai', 118: 'Turkish', 119: 'Ukrainian', 120: 'Vietnamese', 121: 'Other'}, 'part': {0: 'No', 1: 'Yes'}, 'job': {0: 'No', 1: 'Yes'}, 'health': {1: 'Verydissatisfied', 2: 'Dissatisfied', 3: 'Neithersatisfiednordissatisfied', 4: 'Satisfied', 5: 'Verysatisfied'}, 'psyt': {0: 'No', 1: 'Yes'}}

# %% [markdown]
# Substituindo valores no Data Frame usando o mapeamento

# %%
for col in mapeamento.keys():
  if col in df.columns:
    df[col] = df[col].replace(mapeamento[col])
df
# Out:
#        id  age   year    sex       glang part  job  stud_h  \
# 0       2   18  Bmed1    Man  Vietnamese  Yes   No      56
# 1       4   26  Mmed1    Man      French  Yes   No      20
# 2       9   21  Bmed3  Woman      French   No   No      36
# 3      10   21  Bmed2  Woman      French   No  Yes      51
# 4      13   21  Bmed3    Man      French  Yes   No      22
# ..    ...  ...    ...    ...         ...  ...  ...     ...
# 881  1781   21  Bmed2    Man      French  Yes   No      45
# 882  1785   20  Bmed2  Woman      French   No   No      13
# 883  1787   19  Bmed1    Man      French   No   No      50
# 884  1789   24  Mmed2  Woman      French   No   No      20
# 885  1790   22  Bmed3    Man      French   No  Yes      20
#
#                               health psyt  jspe  qcae_cog  qcae_aff  amsp  \
# 0    Neithersatisfiednordissatisfied   No    88        62        27    17
# 1                          Satisfied   No   109        55        37    22
# 2    Neithersatisfiednordissatisfied   No   106        64        39    17
# 3                      Verysatisfied   No   101        52        33    18
# 4                          Satisfied   No   102        58        28    21
# ..                               ...  ...   ...       ...       ...   ...
# 881  Neithersatisfiednordissatisfied   No   106        63        39    28
# 882  Neithersatisfiednordissatisfied   No   113        67        40    21
# 883                    Verysatisfied   No   100        50        31    24
# 884                     Dissatisfied  Yes   120        64        39    21
# 885                    Verysatisfied   No   102        54        26    25
#
#      erec_mean  cesd  stai_t  mbi_ex  mbi_cy  mbi_ea
# 0     0.738095    34      61      17      13      20
# 1     0.690476     7      33      14      11      26
# 2     0.690476    25      73      24       7      23
# 3     0.833333    17      48      16      10      21
# 4     0.690476    14      46      22      14      23
# ..         ...   ...     ...     ...     ...     ...
# 881   0.619048    41      39      23       4      34
# 882   0.809524    26      41      17       5      24
# 883   0.547619    14      45      15       8      31
# 884   0.785714    33      58      22      15      19
# 885   0.571429     5      27      11       9      30
#
# [886 rows x 20 columns]

# %%
df.to_csv('Dados_Saude_Emocional.csv', index=False)
